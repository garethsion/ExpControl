# %%
import ExpControl
# Out:
#   File "c:\users\public\anaconda\lib\site-packages\expcontrol-0.1.0-py3.6.egg\ExpControl\measurements\measurements.py", line 25
#     self.__ic.setup_vna(power=power,avgs=avgs,measure=measure)
#                                                               ^
# TabError: inconsistent use of tabs and spaces in indentation

# %%
meas = ExpControl.Measurements(instr=['vna','prx'])
power = -30
        avgs = 1
        measure = 'S21'
# Out:
# c:\users\public\anaconda\lib\site-packages\qcodes\instrument\parameter.py:274: UserWarning: Wrapping get method of parameter: trace, original get method will not be directly accessible. It is recommended to define get_raw in your subclass instead. Overwriting get will be an error in the future.
#   warnings.warn(f'Wrapping get method of parameter: {self.full_name},'
# Connected to: Agilent Technologies E5071C (serial:MY46526831, firmware:B.13.20) in 0.47s
# Connnected to:    Bruker ER 032M

# %%
meas.trace(2.0e09,12.0e09,npts=20001,bandwidth=1000)
# Out:
# Trace took 0:00:20.805190
# (array([  2.00000000e+09,   2.00050000e+09,   2.00100000e+09, ...,
#           1.19990000e+10,   1.19995000e+10,   1.20000000e+10]),
#  (array([-79.05847236, -76.66265159, -73.64880473, ..., -44.21495188,
#          -44.31386716, -44.21180945]),
#   array([ -85.47238748,  102.1624432 ,   11.66113106, ...,  102.85624793,
#            99.19720983,   95.55606251])))
